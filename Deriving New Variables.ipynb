# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing Datasets
path=r'C:\Users\manis\Documents\Instacart Basket Analysis'

# %%
# Importing Dataset .osv
df_ords_prods_merged=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data', 'orders_products_merged.pkl'))

# %%
# Creating a Subset
df=df_ords_prods_merged[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df.shape
# Out:
# (1000000, 16)

# %%
df.head(20)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2539329        1    prior             1          2                  8
# 2    2539329        1    prior             1          2                  8
# 3    2539329        1    prior             1          2                  8
# 4    2539329        1    prior             1          2                  8
# 5    2398795        1    prior             2          3                  7
# 6    2398795        1    prior             2          3                  7
# 7    2398795        1    prior             2          3                  7
# 8    2398795        1    prior             2          3                  7
# 9    2398795        1    prior             2          3                  7
# 10   2398795        1    prior             2          3                  7
# ...

# %%
# Apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# <ipython-input-8-a657ed9d0bf5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    672525
# Low-range product    314109
# High range            12413
# Not enough data         953
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
df['prices'].min()
# Out:
# 1.0

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\manis\OneDrive\Documents\data analytics\anaconda\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\manis\OneDrive\Documents\data analytics\anaconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# C:\Users\manis\OneDrive\Documents\data analytics\anaconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# C:\Users\manis\OneDrive\Documents\data analytics\anaconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     672525
# Low-range product     314109
# High-range product     12413
# NaN                      953
# Name: price_range_loc, dtype: int64

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# NaN                      30200
# Name: price_range_loc, dtype: int64

# %%
#Printing frequency for column order_dow(Order day of the week)
df_ords_prods_merged['order_dow'].value_counts(dropna=False)
# Out:
# 0    6209808
# 1    5665951
# 6    4500391
# 2    4217868
# 5    4209603
# 3    3844175
# 4    3787263
# Name: order_dow, dtype: int64

# %%
#Creating new list using For Loop
result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
#Print the result list
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Creating new Column in dataframe df_ords_prods_merged
df_ords_prods_merged['busiest_day']=result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22437988
# Busiest day        6209808
# Least busy         3787263
# Name: busiest_day, dtype: int64

# %% [markdown]
# 2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
#Creating new list using For Loop
result1 = []

for value in df_ords_prods_merged["order_dow"]:
  if value == (0 or 1):
    result1.append("Busiest days")
  elif  value == (3 or 4):
    result1.append("slowest days")
  else:
    result1.append("Regularly busy days")

# %%
##Print the result1 list
result1
# Out:
# ['Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'slowest days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
# Creating new Column in dataframe df_ords_prods_merged
df_ords_prods_merged['busiest_days']=result1

# %%
#Checking the frequency of values in new column busiest_days

df_ords_prods_merged['busiest_days'].value_counts(dropna=False)
# Out:
# Regularly busy days    22924933
# Busiest days            5665951
# slowest days            3844175
# Name: busiest_days, dtype: int64

# %% [markdown]
# 4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  ordered_today  product_id  add_to_cart_order  \
# 0                     NaN           True         196                  1
# 1                     NaN           True       14084                  2
# 2                     NaN           True       12427                  3
# 3                     NaN           True       26088                  4
# 4                     NaN           True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
# Printing frequency for column order_hour_of_day
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2764476
# 11    2738647
# 14    2691598
# 15    2664583
# 13    2663346
# 12    2620898
# 16    2537506
# 9     2456751
# 17    2089510
# 8     1719991
# 18    1637956
# 19    1259416
# 20     977049
# 7      891951
# 21     796379
# 22     634743
# 23     402621
# 6      290796
# 0      218951
# 1      115787
# 5       88064
# 2       69435
# 4       53284
# 3       51321
# Name: order_hour_of_day, dtype: int64

# %%
#Creating new list result2 using For Loop
result2 = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value == (10 or 11 or 14 or 15 or 13 or 12 or 16 or 9):
    result2.append("Most orders")
  elif  value == (6 or 0 or 1 or 5 or 2 or 4 or 3):
    result2.append("Fewest orders")
  else:
    result2.append("Average orders")

# %%
# Creating new Column in dataframe df_ords_prods_merged
df_ords_prods_merged['busiest_period_of_day']=result2

# %%
# Checking the frequency of values in new column busiest_period_of_day
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Average orders    29379787
# Most orders        2764476
# Fewest orders       290796
# Name: busiest_period_of_day, dtype: int64

# %%
# Exporting the newly created dataframe as orders_products_merge
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged4.7.pkl'))
